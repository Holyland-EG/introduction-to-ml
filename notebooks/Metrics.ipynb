# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
classification = pd.read_csv('_8b9c6d9ae39e206610c6fd96894615a5_classification.csv')

# %%
scores = pd.read_csv('_eee1b9e8188f61bc35d954fbeb94e325_scores.csv')

# %%
print(score.head(),'\n')
print(classification.head())
# Out:
#    true  score_logreg  score_svm  score_knn  score_tree
# 0     0      0.683832   0.145976   0.787063    0.500000
# 1     1      0.801966   0.239511   1.000000    0.833333
# 2     0      0.382315  -0.245701   0.000000    0.000000
# 3     1      0.506797  -0.137058   0.000000    0.105263
# 4     1      0.488781  -0.154148   0.000000    0.105263
#
#    true  pred
# 0     1     0
# 1     1     1
# 2     1     1
# 3     0     0
# 4     1     1

# %%
from sklearn.metrics import confusion_matrix

# %%
matr = confusion_matrix(classification['true'], classification['pred'])
#tp = 43 fp = 34 fn = 59 tn = 64
# Out:
# array([[64, 34],
#        [59, 43]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
print('accuracy: ',accuracy_score(classification['true'], classification['pred']),'\n')
print('precision: ', precision_score(classification['true'], classification['pred']),'\n')
print('recall: ', recall_score(classification['true'], classification['pred']),'\n')
print('f1: ', f1_score(classification['true'], classification['pred']))
# Out:
# accuracy:  0.535
#
# precision:  0.5584415584415584
#
# recall:  0.4215686274509804
#
# f1:  0.48044692737430167

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(score['true'],score['score_knn'])
# Out:
# 0.6351540616246498

# %%
roc_auc_score(score['true'],score['score_logreg'])
# Out:
# 0.719187675070028

# %%
roc_auc_score(score['true'],score['score_svm'])
# Out:
# 0.7086834733893557

# %%
roc_auc_score(score['true'],score['score_tree'])
# Out:
# 0.6919267707082833

# %%
from sklearn.metrics import precision_recall_curve

# %%
precision_recall_curve(score['true'], score['score_tree'])
# Out:
# (array([0.49      , 0.50273224, 0.50847458, 0.53289474, 0.59848485,
#         0.65178571, 0.67708333, 0.66292135, 0.67073171, 0.7       ,
#         0.71794872, 0.75      , 1.        ]),
#  array([1.        , 0.93877551, 0.91836735, 0.82653061, 0.80612245,
#         0.74489796, 0.66326531, 0.60204082, 0.56122449, 0.42857143,
#         0.28571429, 0.18367347, 0.        ]),
#  array([0.        , 0.1       , 0.10526316, 0.31578947, 0.36363636,
#         0.4       , 0.5       , 0.64285714, 0.7       , 0.83333333,
#         0.92307692, 1.        ]))

# %%
precision_recall_curve(score['true'], score['score_knn'])
# Out:
# (array([0.49      , 0.52903226, 0.53246753, 0.53594771, 0.53947368,
#         0.53642384, 0.54      , 0.54362416, 0.5472973 , 0.55102041,
#         0.55479452, 0.55862069, 0.55555556, 0.55944056, 0.56338028,
#         0.56737589, 0.57142857, 0.56834532, 0.56521739, 0.56934307,
#         0.56617647, 0.57037037, 0.56716418, 0.57142857, 0.57575758,
#         0.58015267, 0.58461538, 0.58914729, 0.59375   , 0.59055118,
#         0.58730159, 0.592     , 0.59677419, 0.60162602, 0.60655738,
#         0.60330579, 0.6       , 0.59663866, 0.59322034, 0.58974359,
#         0.59482759, 0.59130435, 0.5877193 , 0.5840708 , 0.58035714,
#         0.57657658, 0.58181818, 0.58715596, 0.59259259, 0.58878505,
#         0.58490566, 0.58095238, 0.58653846, 0.59223301, 0.58823529,
#         0.59405941, 0.6       , 0.5959596 , 0.60204082, 0.59793814,
#         0.59375   , 0.58947368, 0.58510638, 0.59139785, 0.59782609,
#         0.59340659, 0.58888889, 0.59550562, 0.60227273, 0.59770115,
# ...

# %%
precision_recall_curve(score['true'], score['score_logreg'])
# Out:
# (array([0.49746193, 0.49489796, 0.49230769, 0.49484536, 0.49740933,
#         0.49479167, 0.4973822 , 0.49473684, 0.4973545 , 0.5       ,
#         0.5026738 , 0.5       , 0.4972973 , 0.5       , 0.50273224,
#         0.50549451, 0.50828729, 0.51111111, 0.51396648, 0.51685393,
#         0.51977401, 0.52272727, 0.52571429, 0.52873563, 0.53179191,
#         0.53488372, 0.5380117 , 0.53529412, 0.53846154, 0.54166667,
#         0.54491018, 0.54819277, 0.55151515, 0.54878049, 0.55214724,
#         0.54938272, 0.55279503, 0.55625   , 0.55974843, 0.55696203,
#         0.56050955, 0.56410256, 0.56129032, 0.56493506, 0.56862745,
#         0.56578947, 0.56953642, 0.56666667, 0.5704698 , 0.57432432,
#         0.57142857, 0.57534247, 0.57241379, 0.57638889, 0.58041958,
#         0.58450704, 0.58156028, 0.58571429, 0.58992806, 0.58695652,
#         0.59124088, 0.59558824, 0.6       , 0.59701493, 0.60150376,
#         0.60606061, 0.60305344, 0.6       , 0.60465116, 0.609375  ,
# ...

# %%
precision_recall_curve(score['true'], score['score_svm'])
# Out:
# (array([0.49246231, 0.48989899, 0.49238579, 0.48979592, 0.49230769,
#         0.49484536, 0.49740933, 0.5       , 0.4973822 , 0.49473684,
#         0.49206349, 0.49468085, 0.4973262 , 0.5       , 0.4972973 ,
#         0.5       , 0.50273224, 0.50549451, 0.50828729, 0.51111111,
#         0.51396648, 0.51685393, 0.51977401, 0.52272727, 0.52571429,
#         0.52298851, 0.52601156, 0.52906977, 0.53216374, 0.53529412,
#         0.53846154, 0.54166667, 0.54491018, 0.54819277, 0.54545455,
#         0.54878049, 0.55214724, 0.55555556, 0.55279503, 0.55      ,
#         0.54716981, 0.55063291, 0.5477707 , 0.54487179, 0.5483871 ,
#         0.55194805, 0.55555556, 0.55921053, 0.56291391, 0.56666667,
#         0.5704698 , 0.57432432, 0.57142857, 0.57534247, 0.57931034,
#         0.58333333, 0.58741259, 0.5915493 , 0.58865248, 0.59285714,
#         0.58992806, 0.5942029 , 0.59124088, 0.58823529, 0.59259259,
#         0.59701493, 0.59398496, 0.59090909, 0.59541985, 0.6       ,
# ...

# %%
0
